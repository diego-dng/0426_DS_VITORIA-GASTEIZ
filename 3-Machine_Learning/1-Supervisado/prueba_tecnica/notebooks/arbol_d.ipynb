# %% [markdown]
# # Modelo arbol de decisión.

# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
df = pd.read_csv("../data/coches_proc.csv")

X = df[["kms", "power", "doors", "is_professional"]]
y = df["price"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=11)


arbol_m = DecisionTreeRegressor(max_depth=10, random_state=11)
arbol_m.fit(X_train, y_train)

pred = arbol_m.predict(X_test)

print(arbol_m.feature_importances_)

print("----- METRICAS EVALUACIÓN------")
    
print("MAE: ", metrics.mean_absolute_error(y_test, pred))
print("MAPE: ", metrics.mean_absolute_percentage_error(y_test, pred))
print("MSE: ", metrics.mean_squared_error(y_test, pred))
print("RMSE: ", metrics.root_mean_squared_error(y_test, pred))
# Out:
# [0.31126457 0.66964079 0.01399232 0.00510232]
# ----- METRICAS EVALUACIÓN------
# MAE:  4264.270187981799
# MAPE:  0.3936091233737748
# MSE:  73485257.95763229
# RMSE:  8572.35428325453

# %% [markdown]
# ## modelo 2

# %%
df = pd.read_csv("../data/coches_proc.csv")

X = df[["kms", "power", "doors", "is_professional"]]
y = df["price"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=11)


arbol_m = DecisionTreeRegressor(max_depth=5, random_state=11)
arbol_m.fit(X_train, y_train)

pred = arbol_m.predict(X_test)

print(arbol_m.feature_importances_)

print("----- METRICAS EVALUACIÓN------")
    
print("MAE: ", metrics.mean_absolute_error(y_test, pred))
print("MAPE: ", metrics.mean_absolute_percentage_error(y_test, pred))
print("MSE: ", metrics.mean_squared_error(y_test, pred))
print("RMSE: ", metrics.root_mean_squared_error(y_test, pred))
# Out:
# [0.27450236 0.72146482 0.00403282 0.        ]
# ----- METRICAS EVALUACIÓN------
# MAE:  4993.612640200686
# MAPE:  0.529600645150061
# MSE:  80641630.10843691
# RMSE:  8980.06849129988
