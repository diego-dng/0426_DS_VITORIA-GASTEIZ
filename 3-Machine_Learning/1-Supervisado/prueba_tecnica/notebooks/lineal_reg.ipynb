# %% [markdown]
# # Modelo de regresión lineal.

# %%
import pandas as pd 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
df = pd.read_csv("../data/coches_proc.csv")
df.head()
# Out:
#          make            model  ... is_professional  shift_int
# 0     CITROEN               C1  ...            True          1
# 1        FORD  Transit Connect  ...            True          1
# 2  VOLKSWAGEN        Caravelle  ...            True          1
# 3        FORD          Transit  ...            True          1
# 4     PEUGEOT             3008  ...            True          1
#
# [5 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41251 entries, 0 to 41250
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   make             41251 non-null  object
#  1   model            41251 non-null  object
#  2   version          41251 non-null  object
#  3   price            41251 non-null  int64
#  4   fuel             41251 non-null  object
#  5   year             41251 non-null  float64
#  6   kms              41251 non-null  int64
#  7   power            41251 non-null  float64
#  8   doors            41251 non-null  int64
#  9   shift            41251 non-null  object
#  10  color            41251 non-null  object
#  11  photos           41251 non-null  int64
#  12  is_professional  41251 non-null  bool
#  13  shift_int        41251 non-null  int64
# dtypes: bool(1), float64(2), int64(5), object(6)
# memory usage: 4.1+ MB

# %%
X = df[["kms", "power", "doors", "is_professional", "shift_int"]]
y = df["price"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=11)

lr = LinearRegression()
lr.fit(X_train, y_train)


pred = lr.predict(X_test)

print("----- METRICAS MODELO ------")
print("Intercepto: ", lr.intercept_)
print("Lista coeficientes: ", lr.coef_)


print("MAE: ", metrics.mean_absolute_error(y_test, pred))
print("MAPE: ", metrics.mean_absolute_percentage_error(y_test, pred))
print("MSE: ", metrics.mean_squared_error(y_test, pred))
print("RMSE: ", metrics.root_mean_squared_error(y_test, pred))
# Out:
# ----- METRICAS MODELO ------
# Intercepto:  23.261956666450715
# Lista coeficientes:  [-7.62663691e-02  1.57326542e+02  1.95196485e+02  2.62598189e+03
#  -1.76034974e+03]
# MAE:  5317.312726680301
# MAPE:  0.5936657547617038
# MSE:  128379064.13603263
# RMSE:  11330.448540813935
