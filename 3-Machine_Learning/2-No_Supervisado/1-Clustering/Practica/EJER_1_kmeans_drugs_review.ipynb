# %% [markdown]
# ### Importa los datos
# Dataset con diferentes fármacos, sus efectos y ratings de los clientes.
#
# Importa el dataset *drugLibTrain_raw.tsv*

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn import metrics

# %%
df = pd.read_csv("data/drugLibTrain_raw.tsv", sep= "\t", index_col=0)
df
# Out:
#            urlDrugName  rating           effectiveness  \
# 2202         enalapril       4        Highly Effective
# 3117  ortho-tri-cyclen       1        Highly Effective
# 1146           ponstel      10        Highly Effective
# 3947          prilosec       3    Marginally Effective
# 1951            lyrica       2    Marginally Effective
# ...                ...     ...                     ...
# 1039           vyvanse      10        Highly Effective
# 3281            zoloft       1             Ineffective
# 1664           climara       2    Marginally Effective
# 2621         trileptal       8  Considerably Effective
# 2748          micardis       4    Moderately Effective
#
#                         sideEffects                               condition  \
# 2202              Mild Side Effects  management of congestive heart failure
# 3117            Severe Side Effects                        birth prevention
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3107 entries, 2202 to 2748
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   urlDrugName        3107 non-null   object
#  1   rating             3107 non-null   int64
#  2   effectiveness      3107 non-null   object
#  3   sideEffects        3107 non-null   object
#  4   condition          3106 non-null   object
#  5   benefitsReview     3089 non-null   object
#  6   sideEffectsReview  3032 non-null   object
#  7   commentsReview     3095 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 218.5+ KB

# %%
df.describe(include= "all")
# Out:
#        urlDrugName       rating     effectiveness        sideEffects  \
# count         3107  3107.000000              3107               3107
# unique         502          NaN                 5                  5
# top        lexapro          NaN  Highly Effective  Mild Side Effects
# freq            63          NaN              1330               1019
# mean           NaN     7.006115               NaN                NaN
# std            NaN     2.937582               NaN                NaN
# min            NaN     1.000000               NaN                NaN
# 25%            NaN     5.000000               NaN                NaN
# 50%            NaN     8.000000               NaN                NaN
# 75%            NaN     9.000000               NaN                NaN
# max            NaN    10.000000               NaN                NaN
#
#          condition benefitsReview sideEffectsReview commentsReview
# count         3106           3089              3032           3095
# ...

# %% [markdown]
# ### Descriptive Analysis

# %% [markdown]
# Quedate únicamente con las columnas que podamos manejar: Columnas numéricas y columnas categóricas con pocas categorías (menos de 10)

# %%
df = df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3076 entries, 2202 to 2748
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   urlDrugName        3076 non-null   object
#  1   rating             3076 non-null   int64
#  2   effectiveness      3076 non-null   object
#  3   sideEffects        3076 non-null   object
#  4   condition          3075 non-null   object
#  5   benefitsReview     3058 non-null   object
#  6   sideEffectsReview  3002 non-null   object
#  7   commentsReview     3064 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 216.3+ KB

# %%
df.head()
# Out:
#            urlDrugName  rating         effectiveness          sideEffects  \
# 2202         enalapril       4      Highly Effective    Mild Side Effects
# 3117  ortho-tri-cyclen       1      Highly Effective  Severe Side Effects
# 1146           ponstel      10      Highly Effective      No Side Effects
# 3947          prilosec       3  Marginally Effective    Mild Side Effects
# 1951            lyrica       2  Marginally Effective  Severe Side Effects
#
#                                    condition  \
# 2202  management of congestive heart failure
# 3117                        birth prevention
# 1146                        menstrual cramps
# 3947                             acid reflux
# 1951                            fibromyalgia
#
#                                          benefitsReview  \
# 2202  slowed the progression of left ventricular dys...
# 3117  Although this type of birth control has more c...
# 1146  I was used to having cramps so badly that they...
# ...

# %%
df["effectiveness"].value_counts()
# Out:
# effectiveness
# Highly Effective          1317
# Considerably Effective     916
# Moderately Effective       413
# Ineffective                247
# Marginally Effective       183
# Name: count, dtype: int64

# %%
df["sideEffects"].value_counts()
# Out:
# sideEffects
# Mild Side Effects                1007
# No Side Effects                   918
# Moderate Side Effects             609
# Severe Side Effects               367
# Extremely Severe Side Effects     175
# Name: count, dtype: int64

# %% [markdown]
# #### Transforma las columnas categóricas
#
# Transforma las columnas categoricas a numericas mediante dummies

# %%
mapa = {
    "Ineffective": 0, 
    "Marginally Effective": 1,
    "Moderately Effective": 2,
    "Considerably Effective": 3,
    "Highly Effective": 4
}

df["Effective_int"] = df["effectiveness"].map(mapa)
df
# Out:
# C:\Users\Diego Nuñez\AppData\Local\Temp\ipykernel_2424\2278836293.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Effective_int"] = df["effectiveness"].map(mapa)
#            urlDrugName  rating           effectiveness  \
# 2202         enalapril       4        Highly Effective
# 3117  ortho-tri-cyclen       1        Highly Effective
# 1146           ponstel      10        Highly Effective
# 3947          prilosec       3    Marginally Effective
# 1951            lyrica       2    Marginally Effective
# ...                ...     ...                     ...
# 1039           vyvanse      10        Highly Effective
# 3281            zoloft       1             Ineffective
# 1664           climara       2    Marginally Effective
# ...

# %%
mapa_2 = {
    "No Side Effects": 0, 
    "Mild Side Effects": 1,
    "Moderate Side Effects": 2,
    "Severe Side Effects": 3,
    "Extremely Severe Side Effects": 4
}

df["sideEffect_int"] = df["sideEffects"].map(mapa_2)
df
# Out:
# C:\Users\Diego Nuñez\AppData\Local\Temp\ipykernel_2424\2340901061.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["sideEffect_int"] = df["sideEffects"].map(mapa_2)
#            urlDrugName  rating           effectiveness  \
# 2202         enalapril       4        Highly Effective
# 3117  ortho-tri-cyclen       1        Highly Effective
# 1146           ponstel      10        Highly Effective
# 3947          prilosec       3    Marginally Effective
# 1951            lyrica       2    Marginally Effective
# ...                ...     ...                     ...
# 1039           vyvanse      10        Highly Effective
# 3281            zoloft       1             Ineffective
# 1664           climara       2    Marginally Effective
# ...

# %% [markdown]
# #### Genera el K Means

# %%
X = df[["rating", "Effective_int", "sideEffect_int"]]
print(X.shape)
# Out:
# (3076, 3)

# %%
modelo = KMeans(n_init=15)
kl = modelo.fit_predict(X)

# %%
modelo.n_clusters
# Out:
# 8

# %%
modelo.score(X)
# Out:
# -3363.40282000342

# %% [markdown]
# #### Evalua cual es la mejor K
#
# Utiliza silhouette_score para evaluar cual es la mejor K.

# %%
modelo.inertia_
# Out:
# 3363.40282000342

# %%
print(metrics.silhouette_score(X, kl))
# Out:
# 0.3911614514874954

# %%
nk = range(2, 50)
inertia = []
sc = []
for i in nk:
    stc = StandardScaler()
    X_sc = stc.fit_transform(X)
    modelo = KMeans(n_clusters= i, n_init= 10, random_state=42)
    pred = modelo.fit_predict(X_sc)
    inertia.append(modelo.inertia_)
    sc.append(metrics.silhouette_score(X_sc, pred))

# %%
print("Lista inertia: ", len(inertia))
print("Lista SC: ", len(sc))
# Out:
# Lista inertia:  48
# Lista SC:  48

# %%
plt.figure(figsize=(8, 3.5))
plt.plot(range(2, 50), inertia, "bo-")
plt.xlabel("$k$", fontsize=14)
plt.ylabel("Inertia", fontsize=14)
#plt.axis([1, 8.5, 0, 1300])
plt.show()

# %%
plt.figure(figsize=(8, 3))
plt.plot(range(2, 50), sc, "bo-")
plt.xlabel("$k$", fontsize=14)
plt.ylabel("Silhouette score", fontsize=14)
plt.show()

# %% [markdown]
# Comprueba los resultados y muestra en un pie plot la distribución de los distintos clusters.

# %%
df_cluster = df.copy()
km = KMeans(n_clusters=10, n_init=10).fit(X)
df_cluster["cluster"] = km.labels_
df_cluster
# Out:
#            urlDrugName  rating           effectiveness  \
# 2202         enalapril       4        Highly Effective
# 3117  ortho-tri-cyclen       1        Highly Effective
# 1146           ponstel      10        Highly Effective
# 3947          prilosec       3    Marginally Effective
# 1951            lyrica       2    Marginally Effective
# ...                ...     ...                     ...
# 1039           vyvanse      10        Highly Effective
# 3281            zoloft       1             Ineffective
# 1664           climara       2    Marginally Effective
# 2621         trileptal       8  Considerably Effective
# 2748          micardis       4    Moderately Effective
#
#                         sideEffects                               condition  \
# 2202              Mild Side Effects  management of congestive heart failure
# 3117            Severe Side Effects                        birth prevention
# ...

# %%
df_cluster["cluster"].value_counts()
# Out:
# cluster
# 6    622
# 0    578
# 3    502
# 5    381
# 8    216
# 2    210
# 9    155
# 4    139
# 7    138
# 1    135
# Name: count, dtype: int64

# %%
df_cluster["cluster"].value_counts().plot.pie(autopct = "%.1f%%")
# Out:
# <Axes: ylabel='count'>
