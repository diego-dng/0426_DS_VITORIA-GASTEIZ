# %% [markdown]
# ![imagen](./img/ejercicios.png)
#
# # Ejercicios Clases y Objetos

# %% [markdown]
# ## Ejercicio 1
# Somos una empresa que tiene varias tiendas de electrodomésticos. Necesitamos un programa para manejar las tiendas, ver las ventas que han tenido, cuántos empleados hay, etc... Para ello vamos a modelizar la tienda en una clase, que tendrá las siguientes características:
# * Nombre clase: "Tienda"
# * Atributos comunes:
#     * Tipo: "Electrodomésticos"
#     * Abierta: True
# * Atributos propios de cada tienda:
#     * Nombre - String
#     * Dirección - String
#     * Número de empleados - int
#     * Ventas últimos 3 meses - Lista de 3 numeros
# * Método para calcular las ventas de todos los meses, que devuelva un número con todas las ventas.
# * Método que calcula la media de ventas de los últimos meses, por empleado
# * Método que devuelve en un string el nombre de la tienda, junto con su dirección.
# * Método que obtiene las ventas del último mes.
# * Método para dar una proyección de las ventas en caso de haber invertido X dinero en marketing en esa tienda. Siendo X el parámetro de entrada. Si X es menor de 1000, las ventas de los ultimos 3 meses hubiesen sido de (1.2 x ventas), si es mayor o igual de 1000, las ventas hubiesen sido de (1.5 x venta). El método reescribe el atributo de ventas en los últimos 3 meses, y además devuelve las ventas con el aumento.
#
# Se pide:
# 1. Implementar la clase "Tienda"
# 2. Crear tres tiendas con datos inventados
# 3. Comprueba en al menos una de ellas, todo lo implementado en la clase tienda (sus atributos, media de ventas, ventas/empleado...)
# 3. Calcular las ventas del último mes de todas las tiendas. Para ello usa el bucle `for`
# 4. Imprime por pantalla los nombres de las tiendas cuya dirección lleve el string "Avenida"
# 5. Seguro que ya has hecho este apartado... Documenta la clase :)

# %%
class Tienda:
    tipo = "Electrodomesticos"
    abierta = True


    def __init__(self, nombre:str, direccion:str, n_empleados:int, ventas_trimestre:list):
        self.nombre = nombre
        self.direccion = direccion
        self.empleados = n_empleados
        self.v_trimestre = ventas_trimestre
    
    def total_ventas(self):
        return sum(self.v_trimestre)
    
    def ventas_empleado(self):
        return self.total_ventas()/self.empleados
    
    def info_tienda(self):
        return f"Tienda: {self.nombre}, dirección: {self.direccion}"
    
    def ventas_ultimo_mes(self):
        return self.v_trimestre[-1]
    
    def proyeccion(self, inv):
       
        if inv < 1000:
            print("_")
            for pos, i in enumerate(self.v_trimestre):
                self.v_trimestre[pos] = i * 1.2
            return self.v_trimestre
        elif inv >= 1000:
            for pos, i in enumerate(self.v_trimestre):
                self.v_trimestre[pos] = i * 1.5
            return self.v_trimestre

# %%
tienda_vitoria = Tienda("tienda Vitoria-Gasteiz", "Avenida Gasteiz", 10, [10000, 20000, 30000])
tienda_corunia = Tienda("tienda A Coruña", "Plaza Maria Pita", 8, [8000, 15000, 3000])
tienda_madrid = Tienda("Tienda Madrid", "Paseo de la Castellana", 30, [30000, 12000, 100000])

# %%
print(tienda_vitoria.tipo)
print(tienda_vitoria.abierta)
print(tienda_vitoria.__dict__)

print(tienda_corunia.tipo)
print(tienda_corunia.abierta)
print(tienda_corunia.__dict__)

print(tienda_madrid.tipo)
print(tienda_madrid.abierta)
print(tienda_madrid.__dict__)
# Out:
# Electrodomesticos
# True
# {'nombre': 'tienda Vitoria-Gasteiz', 'direccion': 'Calle Zapateria', 'empleados': 10, 'v_trimestre': [18000.0, 36000.0, 54000.0]}
# Electrodomesticos
# True
# {'nombre': 'tienda A Coruña', 'direccion': 'Plaza Maria Pita', 'empleados': 8, 'v_trimestre': [8000, 15000, 3000]}
# Electrodomesticos
# True
# {'nombre': 'Tienda Madrid', 'direccion': 'Paseo de la Castellana', 'empleados': 30, 'v_trimestre': [30000, 12000, 100000]}

# %%
print(tienda_vitoria.info_tienda())
print(tienda_vitoria.total_ventas())
print(tienda_vitoria.ventas_empleado())
# Out:
# Tienda: tienda Vitoria-Gasteiz, dirección: Calle Zapateria
# 60000
# 6000.0

# %%
print(tienda_vitoria.v_trimestre)
print(tienda_vitoria.proyeccion(800))
print("________________")
print(tienda_madrid.v_trimestre)
print(tienda_vitoria.proyeccion(1220))
# Out:
# [10000, 20000, 30000]
# _
# [12000.0, 24000.0, 36000.0]
# ________________
# [30000, 12000, 100000]
# [18000.0, 36000.0, 54000.0]

# %%
ventas_tiendas = []
for i in [tienda_vitoria, tienda_corunia, tienda_madrid]:
    ventas_tiendas.append(i.ventas_ultimo_mes())

print(ventas_tiendas)
# Out:
# [54000.0, 3000, 100000]

# %%
for i in [tienda_vitoria, tienda_corunia, tienda_madrid]:
    if "Avenida" in i.direccion:
        print(i.nombre)
# Out:
# tienda Vitoria-Gasteiz

# %% [markdown]
# ## Ejercicio 2
# En este ejercicio vamos a implementar una clase *Perro* en Python. La clase tiene las siguientes características:
# * Cosas que sabemos seguro que tiene un perro
#     * Tiene 4 patas
#     * 2 orejas
#     * 2 ojos
#     * Una velocidad de 0. Por defecto, el perro está parado
# * Cuando se inicialice:
#     * El perro será de una determinada raza
#     * Por defecto tendrá pelo "Marrón", a no ser que se diga lo contrario.
#     * Por defecto no tendrá dueño, a no ser que se diga lo contrario.
#
# * Dispondrá también de un método llamado andar, que tiene un argumento de entrada (aumento_velocidad). Este valor se le sumará a la velocidad que ya llevaba el perro.
# * Necesita otro método (parar), donde pondremos la velocidad a 0.
# * Otro método llamado "ladrar", que tendrá un argumento de entrada, y la salida será el siguiente string: "GUAU!" + el argumento de entrada.
#
#
# Se pide:
# * Implementa la clase *Perro*
# * Crea un objeto de tipo *Perro*, sin dueño
# * Comprueba que están bien todos sus atributos
# * Prueba que ande, y comprueba su velocidad
# * Páralo
# * Documenta la clase *Perro*

# %%
class Perro:
    """
        Clase Perro

        Atributos generales: Patas, orejas, ojos y velocidad.

        metodos de la clase: andar(velocidad), parar y ladrar(texto)
        
    """


    patas = 4
    orejas = 2
    ojos = 2
    velocidad = 0


    def __init__(self, raza:str, color:str = "Marron", duenio:bool = False):
        self.raza = raza
        self.color = color
        self.duenio = duenio
    
    def andar(self, vel:float):
        """
            Metodo para aumentar la velocidad del perro. Espera un Float y retorna un string con la velocidad del perro.
        
        """
        self.velocidad = self.velocidad + vel
        return f"La velocidad de {self.raza} es {self.velocidad}"
    
    def parar(self):
        """
            Metodo para detener al perro. Retorna un string con la velocidad del perro.
        
        """
        self.velocidad = 0
        return f"La velocidad de {self.raza} es {self.velocidad}"
    
    def ladrar(self, texto:str):
        """
            Metodo para ladrar. Espera un String y retorna un string con el texto del perro.
        
        """
        return f"¡¡¡GUAUUUU!!!, {texto}"

# %%
perro_1 = Perro("Galgo", "Negro", True)
perro_2 = Perro("Labrador")

# %%
print(perro_1.__dict__)
print(perro_2.__dict__)
# Out:
# {'raza': 'Galgo', 'color': 'Negro', 'duenio': True}
# {'raza': 'Labrador', 'color': 'Marron', 'duenio': False}

# %%
perro_1.andar(5)
# Out:
# 'La velocidad de Galgo es 20'

# %%
perro_1.parar()
# Out:
# 'La velocidad de Galgo es 0'

# %%
perro_1.ladrar("Me gusta Python")
# Out:
# '¡¡¡GUAUUUU!!!, Me gusta Python'
