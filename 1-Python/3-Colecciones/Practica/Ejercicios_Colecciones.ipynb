# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# ## Ejercicio 1
# Dada la siguiente lista:
# > ```ejer_1 = [1,2,3,4,5]```
#
# Inviértela para que quede de la siguiente manera
# > ```ejer_1 = [5,4,3,2,1]```

# %%
ejer_1 = [1,2,3,4,5]

# %%
print(ejer_1)
# Out:
# [5, 4, 3, 2, 1]

# %%
ejer_1.reverse()

print(ejer_1)
# Out:
# [5, 4, 3, 2, 1]

# %%
ejer_1.sort(reverse=True)
print(ejer_1)
# Out:
# [5, 4, 3, 2, 1]

# %%
ejer_1[::-1]
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# ## Ejercicio 3
# Crea una lista nueva con todas las combinaciones de las siguientes dos listas:
# > ```ejer_3_1 = ["Hola", "amigo"]```
# >
# > ```ejer_3_2 = ["Que", "tal"]```
#
# Obten el siguiente output:
#
# ```['Hola Que', 'Hola tal', 'amigo Que', 'amigo tal']```

# %%
ejer_3_1 = ["Hola", "amigo"]
ejer_3_2 = ["Que", "tal"]

# %%
lista_final = []

for i in ejer_3_1:
    for j in ejer_3_2:
        lista_final.append(i + " " + j)

print(lista_final)
# Out:
# ['Hola Que', 'Hola tal', 'amigo Que', 'amigo tal']

# %% [markdown]
# ## Ejercicio 4
# Dada la siguiente lista, encuentra por el índice el valor 45 y sustitúyelo por el 0
# > ```ejer_4 = [20, 47, 19, 29, 45, 67, 78, 90]```

# %%
ejer_4 = [20, 47, 19, 29, 45, 67, 78, 90]

# %%
ejer_4.index(45)
ejer_4[ejer_4.index(45)]
# Out:
# 4

# %%
ejer_4 = [20, 47, 19, 29, 45, 67, 78, 90]
posi = ejer_4.index(45)
ejer_4[posi] = 0
print(ejer_4)
# Out:
# [20, 47, 19, 29, 0, 67, 78, 90]

# %% [markdown]
# ## Ejercicio 5
# Dada la siguiente lista, elimina todos los valores iguales a 3
# > ```ejer_5 = [3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3]```
#
# TIP: No intentes eliminar elementos sobre la lista que estás iterando. Haz una copia con `ejer_5.copy()`.

# %%
ejer_5 = [3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3]
ejer_5_final = []

for i in ejer_5:
    if i != 3:
        ejer_5_final.append(i)

print(ejer_5_final)
# Out:
# [20, 47, 19, 29, 45, 67, 78, 90]

# %%
ejer_5 = [3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3]

for i in ejer_5.copy():
    if i == 3:
        ejer_5.remove(i)

print(ejer_5)
# Out:
# [20, 47, 19, 29, 45, 67, 78, 90]

# %% [markdown]
# ## Ejercicio 6
# 1. Crea una tupla con 3 elementos
# 2. Crea otra tupla con un elemento y comprueba su tipo
# 3. Crea una tupla con elementos de diferentes tipos
# 4. Imprime por pantalla el primer y último elemento de la tupla del apartado 3. Usa `len` para el último
# 5. Añade un elemento a la tupla del apartado 3.
# 6. Eliminar un elemento de la tupla del apartado 5, que se encuentre más o menos en la mitad.
# 7. Convierte la tupla del apartado 5 en una lista

# %%
tupla_6 = (1,2,3)
tupla_6_2 = ("hola",0)
tupla_6_3 = (1, True, "hola")
print(type(tupla_6_2))
print(tupla_6[0] , ", " , tupla_6[-1])
print(len(tupla_6)-1)
# Out:
# <class 'tuple'>
# 1 ,  3
# 2

# %%
tupla_6_3 = list(tupla_6_3)
tupla_6_3.append(5)
tupla_6_3 = tuple(tupla_6_3)
print(tupla_6_3)
print(type(tupla_6_3))
# Out:
# (1, True, 'hola', 5, 5)
# <class 'tuple'>

# %%
tupla_6_5 = (1, True, 'hola', 5, 5)
tupla_6_5 = list(tupla_6_5)
tupla_6_5.pop(len(tupla_6_5)//2)
tupla_6_5 = tuple(tupla_6_5)
print(tupla_6_5)
# Out:
# (1, True, 5, 5)

# %% [markdown]
# ## Ejercicio 7
# Concatena todos los elementos de la tupla en un único string. Para ello utiliza el metodo `.join()` de los Strings
# > ```ejer_7 = ("cien", "cañones", "por", "banda")```
#
# Resultado: `cien cañones por banda`

# %%
ejer_7 = ("cien", "cañones", "por", "banda")

print(*ejer_7)
print(type(ejer_7))
# Out:
# cien cañones por banda
# <class 'tuple'>

# %%
" ".join(ejer_7)
# Out:
# 'cien cañones por banda'

# %%
frase = " "
frase.join(ejer_7)
# Out:
# 'cien cañones por banda'

# %% [markdown]
# ## Ejercicio 8
# Obten el tercer elemento de la siguiente tupla, y el tercero empezando por la cola
# > ```ejer_8 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3)```

# %%
ejer_8 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3)

print(ejer_8[2])
print(ejer_8[-3])
# Out:
# 3
# 90

# %% [markdown]
# ## Ejercicio 11
# Convierte la siguiente lista en un diccionario
# > ```ejer_11 = [("x", 1), ("x", 2), ("x", 3), ("y", 1), ("y", 2), ("z", 1)]```
#
# TIP: Puedes usar dos variables de control en un bucle `for`. Una por cada valor de las tuplas.

# %%
ejer_11 = [("x", 1), ("x", 2), ("x", 3), ("y", 1), ("y", 2), ("z", 1)]

dict_11 = {}
for clave, valor in ejer_11:
    if clave not in dict_11:
        dict_11[clave] = []
    dict_11[clave].append(valor)

dict_11
# Out:
# {'x': [1], 'y': [1], 'z': [1]}

# %% [markdown]
# ## Ejercicio 12
# 1. Crea una lista ordenada ascendente con las claves del diccionario
# 2. Crea otra lista ordenada descendente con los valores
# 3. Añade una nueva clave/valor
# 4. Busca la clave igual a 2 dentro del diccionario
# 5. Itera la clave y el valor del diccionario con un único for
# > ```ejer_12 = {4:78, 2:98, 8:234, 5:29}```

# %%
ejer_12 = {4:78, 2:98, 8:234, 5:29}

# %%
print(sorted(list(ejer_12.keys())))
print(sorted(list(ejer_12.values())))
# Out:
# [2, 4, 5, 8]
# [29, 78, 98, 234]

# %%
print(sorted(list(ejer_12.values()), reverse= True))
# Out:
# [234, 98, 78, 29]

# %%
ejer_12[9] = 1994
print(ejer_12)
# Out:
# {4: 78, 2: 98, 8: 234, 5: 29, 9: 1994}

# %%
print(2 in ejer_12)
ejer_12[2]
# Out:
# True
# 98

# %%
for clave, valor in ejer_12.items():
    print(clave)
    print(valor)
# Out:
# 4
# 78
# 2
# 98
# 8
# 234
# 5
# 29
# 9
# 1994

# %% [markdown]
# ## Ejercicio 13
# Junta ambos diccionarios. Para ello, utiliza `update`
# > ```ejer_13_1 = {1: 11, 2: 22}```
# >
# > ```ejer_13_2 = {3: 33, 4: 44}```

# %%
ejer_13_1 = {1: 11, 2: 22}
ejer_13_2 = {3: 33, 4: 11}

# %%
ejer_13_1.update(ejer_13_2)
print(ejer_13_1)
# Out:
# {1: 11, 2: 22, 3: 33, 4: 11}

# %% [markdown]
# ## Ejercicio 14
# Suma todos los valores del dicionario
# > ```ejer_14 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}```

# %%
ejer_14 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}

# %%
list_14 = list(ejer_14.values())
print(list_14)
print(sum(list_14))
# Out:
# [11, 22, 33, 44, 55]
# 165

# %% [markdown]
# ## Ejercicio 15
# Multiplica todos los valores del diccionario
# > ```ejer_15 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}```

# %%
ejer_15 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}

# %%
print(ejer_15.values())
# Out:
# dict_values([11, 22, 33, 44, 55])

# %%
prod = 1
for i in ejer_15.values():
    prod = prod*i

print(prod)
# Out:
# 11
# 22
# 33
# 44
# 55
# 19326120

# %%
import math

# %%
math.prod(ejer_15.values())
# Out:
# 19326120

# %%
import numpy as np

# %%
np.prod(list(ejer_15.values()))
# Out:
# np.int64(19326120)

# %% [markdown]
# ## Ejercicio 16
# 1. Crea un set de tres elementos
# 2. Añade un cuarto
# 3. Elimina el último elemento añadido
# 4. Elimina el elemento 10, si está presente. Usa `discard()`

# %%
ejer_16 = {1, "2", 3.0}
ejer_16.add(9)
print(ejer_16)
# Out:
# {1, 3.0, '2', 9}

# %%
ejer_16.remove(9)

# %%
ejer_16.discard(3)
print(ejer_16)
# Out:
# {1}
