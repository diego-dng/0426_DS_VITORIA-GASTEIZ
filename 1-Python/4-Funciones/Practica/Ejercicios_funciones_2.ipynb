# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios funciones
# ## Ejercicio 1
# Escribe una función que convierta números del 1 al 7 en nombres de los dias de la semana. La función constará de un único argumento numérico y una salida de tipo string

# %%
dia_semana = 0

if dia_semana == 1:
    dia = "Lunes"
elif dia_semana == 2:
    dia = "Martes"
elif dia_semana == 3:
    dia = "Miercoles"
elif dia_semana == 4:
    dia = "Jueves"
elif dia_semana == 5:
    dia = "Viernes"
elif dia_semana == 6:
    dia = "Sabado"
elif dia_semana == 7:
    dia = "Domingo"
else:
    dia = "Numero fuera de rango"

print(dia)
# Out:
# Numero fuera de rango

# %%
def dia_semana(numero):
    """
    FUNCION QUE PIDE UN NUMERO ENTRE 1 Y 7 Y TE 
    DA EL NUMERO DE LA SEMANA
    """

    try:
        numero = int(numero)
        print(type(numero))
        if numero == 1:
            dia = "Lunes"
        elif numero == 2:
            dia = "Martes"
        elif numero == 3:
            dia = "Miercoles"
        elif numero == 4:
            dia = "Jueves"
        elif numero == 5:
            dia = "Viernes"
        elif numero == 6:
            dia = "Sabado"
        elif numero == 7:
            dia = "Domingo"
        else:
            dia = "Numero fuera de rango"

        return dia
    except:
        return "Tiene que ser un numero"

# %%
res = dia_semana(4)
print(res)
res1 = dia_semana(5)
print(res1)
res2 = dia_semana(12)
print(res2)
# Out:
# Jueves
# Viernes
# Numero fuera de rango

# %%
x = input("Dime el dia de la semana(valor numerico)")

res = dia_semana(x)
print(res)
# Out:
# Tiene que ser un numero

# %% [markdown]
# ## Ejercicio 2
# En el ejercicio 8 de flujos de control, creábamos una pirámide invertida de números desde el 5. Crea una función que replique el comportamiento de la pirámide, y utiliza un único parámetro de entrada de la función para determinar el número de filas de la pirámide.
#
# 5 4 3 2 1
#
# 4 3 2 1
#
# 3 2 1
#
# 2 1
#
# 1

# %%
lista = [5, 4, 3, 2, 1]

for i in lista.copy():
    print(*lista)
    lista.remove(i)
# Out:
# 5 4 3 2 1
# 4 3 2 1
# 3 2 1
# 2 1
# 1

# %%
lista = list(range(5, 0, -1))
print(lista)
# Out:
# [5, 4, 3, 2, 1]

# %%
def piramide(num):
    lista = list(range(num, 0, -1))
    for i in lista.copy():
        print(*lista)
        lista.remove(i)

# %%
piramide(5)
# Out:
# 5 4 3 2 1
# 4 3 2 1
# 3 2 1
# 2 1
# 1

# %% [markdown]
# ## Ejercicio 3
# Escribe una función que compare dos números. La función tiene dos argumentos y hay tres salidas posibles: que sean iguales, que el primero sea  mayor que el segundo, o que el segundo sea mayor que el primero

# %%
def comp(num1, num2):
    print(num1)
    print(num2)
    if num1 == num2:
        return "Son iguales"
    elif num1 > num2:
        return "El primer numero es mayor que el segundo"
    else:
        return "El segundo numero es mayor que el primero"

# %%
res = comp(1)
print(res)
# Out:
# 1
# 0
# El primer numero es mayor que el segundo

# %% [markdown]
# ## Ejercicio 4
# Escribe una función que sea un contador de letras. En el primer argumento tienes que introducir un texto, y el segundo que sea una letra que contar. La función tiene que devolver un entero con el número de veces que aparece esa letra, tanto mayúscula, como minúscula

# %%
texto = "hola mundo, soy Diego profesor de Data"
letra = "a"

texto = texto.lower()
print(texto)

print(texto.count(letra))
# Out:
# hola mundo, soy diego profesor de data
# 3

# %%
def cont_letras(texto, letra):
    texto = texto.lower()
    letra = letra.lower()
    return texto.count(letra)

# %%
texto = "hola mundo, soy Diego profesor de Data"
letra = "a"

res = cont_letras(letra = letra, texto = texto)
print(res)
# Out:
# 3

# %% [markdown]
# ## Ejercicio 5
# Escribe una función que tenga un único argumento, un string. La salida de la función tiene que ser un diccionario con el conteo de todas las letras de ese string, siendo la clave la letra y el valor el conteo.

# %%
texto = "hola mundo, soy Diego profesor de Data"
dict = {}

texto = texto.lower()

for i in texto:
    if i == " ":
        continue
    dict[i] = texto.count(i)

print(dict)
# Out:
# {'h': 1, 'o': 6, 'l': 1, 'a': 3, 'm': 1, 'u': 1, 'n': 1, 'd': 4, ',': 1, 's': 2, 'y': 1, 'i': 1, 'e': 3, 'g': 1, 'p': 1, 'r': 2, 'f': 1, 't': 1}

# %%
def conteo(texto):
    dict = {}
    texto = texto.lower()

    for i in texto:
        if i == " ":
            continue
        dict[i] = texto.count(i)

    return dict

# %%
texto = "hola mundo, soy Diego profesor de Data"

res = conteo(texto)
print(res)
# Out:
# {'h': 1, 'o': 6, 'l': 1, 'a': 3, 'm': 1, 'u': 1, 'n': 1, 'd': 4, ',': 1, 's': 2, 'y': 1, 'i': 1, 'e': 3, 'g': 1, 'p': 1, 'r': 2, 'f': 1, 't': 1}

# %% [markdown]
# ## Ejercicio 6
# Escribir una función que añada o elimine elementos en una lista. La función necesita los siguientes argumentos:
# * lista: la lista donde se añadirán o eliminarán los elementos
# * comando: "add" o "remove"
# * elemento: Por defecto es None.
#
# Tendrá como salida la lista

# %%
def modificar_lista(lista, comando, elemento = None):
    comando = comando.lower()
    if comando == "add":
        lista.append(elemento)
    elif comando == "remove":
        if elemento in lista:
            lista.remove(elemento)
        else:
            return "elemento no encontrado en la lista"
    else:
        return "comando incorrecto"
    
    return lista

# %%
lista = list(range(1,14,2)) 
print(lista)
res = modificar_lista(lista, "add", True)
print(res)
# Out:
# [1, 3, 5, 7, 9, 11, 13]
# [1, 3, 5, 7, 9, 11, 13, True]

# %% [markdown]
# ## Ejercicio 7
# Crea una función que reciba un número arbitrario de palabras, y devuelva una frase completa, separando las palabras con espacios.

# %%
def frase(*ar):
    print(type(ar))
    return " ".join(ar)

# %%
res = frase("hola", "mundo", "Fernando Alonso")
print(res)
# Out:
# <class 'tuple'>
# hola mundo Fernando Alonso

# %% [markdown]
# ## Ejercicio 8 - TEMARIO SIN VER EN CLASE!!!!
# Escribe un programa que obtenga el enésimo número de la [serie de Fibonacci](https://es.wikipedia.org/wiki/Sucesi%C3%B3n_de_Fibonacci). Tienes que crear una función recursiva con un único argumento.
#
# ```Python
# fibonacci(2) = 1
# fibonacci(4) = 3
# fibonacci(5) = 5
# fibonacci(8) = 21
# ```

# %% [markdown]
# fibonacci(n) = fibonacci(n-1) + fibonacci(n-2)

# %%
def fibonacci(n):
    if n >= 0:
        if n == 0 or n == 1:
            return n
        else:
            return fibonacci(n-1) + fibonacci(n-2)
    else:
        return "El numero es negativo"

# %%
res = fibonacci(-9)
print(res)
# Out:
# El numero es negativo

# %% [markdown]
# ## Ejercicio 9
# Define en una única celda las siguientes funciones:
# * Función que calcule el área de un cuadrado
# * Función que calcule el área de un triángulo
# * Función que calcule el área de un círculo
#
# En otra celda, calcular el area de:
# * Dos círculos de radio 10 + un triángulo de base 3 y altura 7
# * Un cuadrado de lado = 10 + 3 círculos (uno de radio = 4 y los otros dos de radio = 6) + 5 triángulos de base = 2 + altura = 4

# %%
from math import pi

pi
# Out:
# 3.141592653589793

# %%
def area_cuadrado(l):
    return l**2

def area_triangulo(b,a):
    return b*a / 2

def area_circulo(r):
    return pi *r **2

# %%
print("AREA 1:", round(area_circulo(10)*2, 2) + round(area_triangulo(3, 7),2))
print("AREA 2:", round(area_cuadrado(10) + area_circulo(4) + area_circulo(6)*2 + area_triangulo(2,4)*5, 2))
# Out:
# AREA 1: 638.82
# AREA 2: 396.46

# %% [markdown]
# ## Ejercicio 10
#
# Guarda las funciones de estos ejercicios en un fichero llamado `funciones.py` e importalas desde este jupyter notebook para probar que puedes hacer uso de ellas.

# %%
print(area_cuadrado(4))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(area_cuadrado(4))
#
# NameError: name 'area_cuadrado' is not defined

# %%
import funciones as f

res = f.dia_semana(3)
print(res)
# Out:
# <class 'int'>
# Miercoles
