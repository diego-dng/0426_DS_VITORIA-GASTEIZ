# %% [markdown]
# ## Ejercicio descargas

# %% [markdown]
# Python es un lenguaje de propósito general, por lo que podemos desarrollar otros programas,
# aparte de ciencia de datos, que nos permitan montar dashboards, crear APIs o automatizar
# procesos. En este caso vas a automatizar un proceso, en el que tendrás que desarrollar un
# script que ordene todos los archivos de una carpeta, dependiendo de la extensión de los
# mismos.
#
#
# El objetivo es ordenar la típica carpeta de cajón desastre donde se nos acumulan archivos de
# todos los formatos como: imágenes, words, presentaciones, excels, ejecutables, zips, etc... Y
# que no vamos a ir viendo archivo a archivo, ordenándolos.... La solución suele ser eliminarlo
# todo. Vamos a intentar no tener que llegar a eso, ordenando los ficheros automáticamente en
# carpetas y revisar las que nos interesen. La típica carpeta donde aplicaríamos este programa es
# la de “Descargas”, donde se suelen acumular muchos archivos temporales.
#
#
# Por tanto, **el programa tiene que guardar los archivos de la carpeta “Descargas” (o cualquier
# otra donde acumules mucho archivo temporal) en los siguientes directorios dentro de la
# propia carpeta “Descargas”**:
# - Imagenes
# - Documentos
# - Software
# - Otros
#
# Cada vez que ejecutes el script, automáticamente se ordenarán todos los archivos en sus
# correspondientes carpetas.

# %%
doc_types = ('.doc', '.docx', '.txt', '.pdf', '.xls', '.ppt', '.xlsx', '.pptx')
img_types = ('.jpg', '.jpeg', '.png', '.svg', '.gif')
software_types = ('.exe', '.py','.ipynb')

# %% [markdown]
# ### 1. Crea un un programa con el flujo principal y encapsúlalo en funciones.

# %%
import os
import shutil

# %%
os.getcwd()
# Out:
# 'c:\\Users\\Diego Nuñez\\Desktop\\REPO_0426\\0426_DS_VITORIA-GASTEIZ\\2-Data_analysis\\3-Sources\\Archivos\\Practica'

# %%
os.chdir("C://Users//Diego Nuñez//Desktop//archivos")

# %%
ruta = os.getcwd()
ruta
# Out:
# 'C:\\Users\\Diego Nuñez\\Desktop\\archivos'

# %%
os.listdir()
# Out:
# ['2-Build_autonomous_car.ipynb',
#  'archive (6).zip',
#  'descarga.jfif',
#  'IMG_20240927_115037_00_107.jpg',
#  'Intro_ML.pdf',
#  'Intro_ML.pptx',
#  'OllamaSetup.exe']

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Diego Nuñez\\Desktop\\archivos'

# %%
def crear_carpetas():
    os.makedirs(os.getcwd() + "/Documentos", exist_ok= True)
    os.makedirs(os.getcwd() + "/Imagenes", exist_ok= True)
    os.makedirs(os.getcwd() + "/Software", exist_ok= True)
    os.makedirs(os.getcwd() + "/Otros", exist_ok= True)
    
    return "Carpetas creadas correctamente"

# %%
os.listdir()
# Out:
# ['2-Build_autonomous_car.ipynb',
#  'archive (6).zip',
#  'descarga.jfif',
#  'Documentos',
#  'Imagenes',
#  'IMG_20240927_115037_00_107.jpg',
#  'Intro_ML.pdf',
#  'Intro_ML.pptx',
#  'OllamaSetup.exe',
#  'Otros',
#  'Software']

# %%
for i in os.listdir():
    print(i)
# Out:
# 2-Build_autonomous_car.ipynb
# archive (6).zip
# descarga.jfif
# Documentos
# Imagenes
# IMG_20240927_115037_00_107.jpg
# Intro_ML.pdf
# Intro_ML.pptx
# OllamaSetup.exe
# Otros
# Software

# %%
ruta = os.getcwd()

for archivos in os.listdir(ruta):
    ruta_archivo = os.getcwd() +"\\"+ archivos
    print(ruta_archivo)
    if os.path.isdir(ruta_archivo):
        print(archivos, " es una carpeta")
    elif archivos.endswith(doc_types):
        print("doc: ",archivos)
        shutil.move(ruta_archivo, "C:\\Users\\Diego Nuñez\\Desktop\\archivos\\Documentos")
    elif archivos.endswith(img_types):
        print("img:", archivos)
        shutil.move(ruta_archivo, "C:\\Users\\Diego Nuñez\\Desktop\\archivos\\Imagenes")
    elif archivos.endswith(software_types):
        print("soft:" ,archivos)
        shutil.move(ruta_archivo, "C:\\Users\\Diego Nuñez\\Desktop\\archivos\\Software")
    else:
        print("otros: ", archivos)
        shutil.move(ruta_archivo, "C:\\Users\\Diego Nuñez\\Desktop\\archivos\\Otros")
# Out:
# C:\Users\Diego Nuñez\Desktop\archivos\descarga.jfif
# otros:  descarga.jfif
# C:\Users\Diego Nuñez\Desktop\archivos\Documentos
# Documentos  es una carpeta
# C:\Users\Diego Nuñez\Desktop\archivos\Imagenes
# Imagenes  es una carpeta
# C:\Users\Diego Nuñez\Desktop\archivos\IMG_20240927_115037_00_107.jpg
# img: IMG_20240927_115037_00_107.jpg
# C:\Users\Diego Nuñez\Desktop\archivos\Intro_ML.pdf
# doc:  Intro_ML.pdf
# C:\Users\Diego Nuñez\Desktop\archivos\Intro_ML.pptx
# doc:  Intro_ML.pptx
# C:\Users\Diego Nuñez\Desktop\archivos\OllamaSetup.exe
# soft: OllamaSetup.exe
# C:\Users\Diego Nuñez\Desktop\archivos\Otros
# Otros  es una carpeta
# C:\Users\Diego Nuñez\Desktop\archivos\Software
# Software  es una carpeta

# %% [markdown]
# ### 2. Crea una clase Fichero en clase.py y un main.py con el programa principal partiendo de esa clase.
